# %%
import matplotlib.pyplot as plt
from pickleshare import pickle
import pickle as pkl
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')

print("Size of:")
print("Training-set:\t\t{}".format(len(mnist.train.labels)))
print("- Validation-set:\t{}".format(len(mnist.test.labels)))
print("- Test-set:\t\t{}".format(len(mnist.validation.labels)))

#defining placeholder variables for inputs

def placeholder(img_dim,z_dim):
  img_ph=tf.placeholder(tf.float32,(None,img_dim[0],img_dim[1],img_dim[2]),name="image_data")
  z_ph=tf.placeholder(tf.float32,(None,z_dim),name="hidden_data")
  return img_ph,z_ph


def generator(z,out_dim,n_units,reuse):
  with tf.variable_scope('generator',reuse=reuse):
    #the hidden layer with n_units
    dim=7
    depth=256
    h1=tf.layers.dense(z,dim*dim*depth,activation=tf.nn.relu)
    h1=tf.layers.batch_normalization(h1)
    h1=tf.reshape(h1,[-1,dim,dim,depth])

    h1=tf.keras.layers.UpSampling2D((2,2))(h1)   #use tf.image.resize_nearest_neighbor
    h1=tf.layers.conv2d_transpose(h1,64,(4,4),padding='same',activation=tf.nn.relu)

    h1=tf.keras.layers.UpSampling2D((2,2))(h1)   #use tf.image.resize_nearest_neighbor
    h1=tf.layers.conv2d_transpose(h1,32,(4,4),padding='same',activation=tf.nn.relu)


    h1=tf.keras.layers.UpSampling2D((2,2))(h1)   #use tf.image.resize_nearest_neighbor
    h1=tf.layers.conv2d_transpose(h1,32,(4,4),padding='same',activation=tf.nn.relu)

    h1=tf.layers.conv2d_transpose(h1,16,(4,4),padding='same',activation=tf.nn.relu)

    h1=tf.layers.conv2d_transpose(h1,16,(4,4),padding='same',activation=tf.nn.relu)

    h1=tf.layers.conv2d_transpose(h1,1,(4,4),padding='same',activation=tf.nn.relu)

    h1=tf.contrib.layers.flatten(h1)
    #output layer
    logits=tf.layers.dense(h1,784,activation=None)
    out=tf.tanh(logits)
    return out #this is somewhat important

def discriminator(x,n_units,reuse=False):
  with tf.variable_scope('discriminator',reuse=reuse):
    #hidden layer with n_units
    print("lol"+str(x.shape))
    h1=tf.layers.conv2d(x,64,(3,3), padding='same',activation=tf.nn.relu,reuse=None)
    h1=tf.layers.dropout(h1,0.25)

    h1=tf.layers.conv2d(h1,32,(3,3),padding='same',activation=tf.nn.relu,reuse=None)
    h1=tf.layers.dropout(h1,0.2)

    h1=tf.layers.conv2d(h1,16,(3,3),padding='same',activation=tf.nn.relu,reuse=None)
    h1=tf.layers.dropout(h1,0.25)

    h1=tf.layers.conv2d(h1,16,(3,3),padding='same',activation=tf.nn.relu,reuse=None)
    h1=tf.layers.dropout(h1,0.25)

    h1=tf.layers.conv2d(h1,16,(3,3),padding='same',activation=tf.nn.relu,reuse=None)
    h1=tf.layers.dropout(h1,0.25)
    
    h1=tf.layers.conv2d(h1,5,(3,3),padding='same',activation=tf.nn.relu,reuse=None)

    h1=tf.contrib.layers.flatten(h1)
    #output layer
    logits=tf.layers.dense(h1,1,activation=None)
    out=tf.sigmoid(logits)
    return out,logits


input_size=[28,28,1]
z_dim=50
g_hidden=128
d_hidden=128
smoothing_param=0.1 # to keep the sigmoid betwen 0 and 0.9

#graph initiation
tf.reset_default_graph()
real_x, input_z=placeholder(input_size,z_dim)
#generator node
g_model=generator(input_z,input_size[0]*input_size[1]*input_size[2],g_hidden,reuse=False)
print("g_model"+str(g_model.shape))
g_model=tf.reshape(g_model,[-1,28,28,1])
#discriminator node
#1. for real data
#2. for fake data(we'll use the same layer again )
d_model_real,d_logit_real=discriminator(real_x,d_hidden,False)
d_model_fake,d_logit_fake=discriminator(g_model,d_hidden,True)

#loss functions
#discriminator loss -> real loss,->fake loss
d_real_loss=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_real,labels=tf.ones_like(d_logit_real)*(1-smoothing_param)))
d_fake_loss=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake,labels=tf.zeros_like(d_logit_fake)))

total_d_loss=d_real_loss+d_fake_loss

#generator loss
g_loss=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake,labels=tf.ones_like(d_logit_fake)))

#optimizer
lr=0.0005
t_var=tf.trainable_variables()
d_var=[var for var in t_var if var.name.startswith('discriminator')]
g_var=[var for var in t_var if var.name.startswith('generator')]

d_optimizer=tf.train.AdamOptimizer(lr).minimize(total_d_loss,var_list=d_var)
g_optimizer=tf.train.AdamOptimizer(lr).minimize(g_loss,var_list=g_var)


#start training

batch_size=128 #power of 2
epochs=15 # i don't have a GPU
samples=[] #to print some generated images
loss=[] #need to calm my heart

#save generator variables
gen_saved = tf.train.Saver(var_list=g_var)	
k=2
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  for i in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
      print(mnist.train.num_examples//batch_size)
      print("training.......")
      batch=mnist.train.next_batch(batch_size) #takes a batch size of 128 random images
      images=batch[0].reshape((batch_size,28,28,1))
      images=images*2-1
      print("batch_size"+str(images.shape))

      #sample z
      for iii in range(k):
        z=np.random.uniform(-1,1,size=(batch_size,z_dim))
        sess.run(d_optimizer,feed_dict={real_x:images,input_z:z})
      print("discriminator done")
     
      z=np.random.uniform(-1,1,size=(batch_size,z_dim))
      sess.run(g_optimizer,feed_dict={input_z:z})
      print("generator done")
      print("end of iteration {} of epcoh {}".format(ii,i))

      train_loss_d=sess.run(total_d_loss,{input_z:z,real_x:images})
      train_loss_g=g_loss.eval({input_z:z})
      print("Epoch {}/{}...".format(i+1, epochs),
                  "Discriminator Loss: {:.4f}...".format(train_loss_d),
                  "Generator Loss: {:.4f}".format(train_loss_g))
    #loss.append((train_loss_d,train_loss_g))
    sample_z = np.random.uniform(-1, 1, size=(16, z_dim))
    gen_samples=sess.run(generator(input_z,input_size,g_hidden,reuse=True),feed_dict={input_z:sample_z})
    samples.append(gen_samples)
    gen_saved.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
  pkl.dump(samples, f)


def view_samples(epoch, samples):
  print("i'm here")
  fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
  for ax, img in zip(axes.flatten(), samples[epoch]):
    ax.xaxis.set_visible(True)
    ax.yaxis.set_visible(True)
    im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
  return fig, axes

with open('train_samples.pkl', 'rb') as f:
  samples = pkl.load(f)

print("calling")
print(len(samples))
p=view_samples(-1,samples)
plt.show()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Size of:
# Training-set:		55000
# - Validation-set:	10000
# - Test-set:		5000
# g_model(?, 784)
# lol(?, 28, 28, 1)
# lol(?, 28, 28, 1)
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 0 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.3340... Generator Loss: 0.6924
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 1 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.2788... Generator Loss: 0.6675
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 2 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.3097... Generator Loss: 0.5454
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 3 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.5953... Generator Loss: 0.3444
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 4 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.6502... Generator Loss: 0.3247
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 5 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.4537... Generator Loss: 0.4403
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 6 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.3335... Generator Loss: 0.5635
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 7 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.2915... Generator Loss: 0.6441
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 8 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.2741... Generator Loss: 0.6803
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 9 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.2580... Generator Loss: 0.6933
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 10 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.2219... Generator Loss: 0.7003
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 11 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.1675... Generator Loss: 0.7053
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 12 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.1073... Generator Loss: 0.7117
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 13 of epcoh 0
# Epoch 1/15... Discriminator Loss: 1.0408... Generator Loss: 0.7231
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 14 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.9751... Generator Loss: 0.7520
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 15 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.9088... Generator Loss: 0.8203
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 16 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.8270... Generator Loss: 0.9389
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 17 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.7289... Generator Loss: 1.1104
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 18 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.6225... Generator Loss: 1.3812
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 19 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.5030... Generator Loss: 1.8663
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 20 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.4095... Generator Loss: 2.6409
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 21 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3636... Generator Loss: 3.7410
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 22 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3472... Generator Loss: 5.0907
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 23 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3579... Generator Loss: 6.3743
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 24 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3507... Generator Loss: 7.6699
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 25 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3510... Generator Loss: 8.6234
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 26 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3475... Generator Loss: 9.2595
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 27 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3518... Generator Loss: 9.7166
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 28 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3448... Generator Loss: 9.6666
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 29 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3424... Generator Loss: 9.6039
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 30 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3378... Generator Loss: 9.2777
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 31 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3379... Generator Loss: 8.9292
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 32 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3338... Generator Loss: 8.5525
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 33 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3356... Generator Loss: 8.1259
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 34 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3333... Generator Loss: 7.9002
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 35 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3341... Generator Loss: 7.5346
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 36 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3332... Generator Loss: 7.4273
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 37 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3322... Generator Loss: 7.1369
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 38 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3314... Generator Loss: 7.0623
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 39 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3326... Generator Loss: 7.0134
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 40 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3320... Generator Loss: 6.8102
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 41 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3312... Generator Loss: 6.8650
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 42 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3313... Generator Loss: 6.8282
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 43 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3317... Generator Loss: 6.7342
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 44 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3303... Generator Loss: 6.8748
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 45 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3291... Generator Loss: 6.8515
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 46 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3312... Generator Loss: 6.8060
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 47 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3303... Generator Loss: 6.9804
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 48 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3295... Generator Loss: 7.0686
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 49 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3317... Generator Loss: 6.9928
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 50 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3293... Generator Loss: 7.1633
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 51 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3290... Generator Loss: 7.2460
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 52 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3304... Generator Loss: 7.1767
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 53 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3288... Generator Loss: 7.2925
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 54 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3295... Generator Loss: 7.3876
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 55 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3288... Generator Loss: 7.3192
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 56 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3280... Generator Loss: 7.3580
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 57 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3288... Generator Loss: 7.4624
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 58 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3282... Generator Loss: 7.4536
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 59 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3288... Generator Loss: 7.4651
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 60 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3284... Generator Loss: 7.5552
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 61 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3276... Generator Loss: 7.5891
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 62 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3289... Generator Loss: 7.5339
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 63 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3278... Generator Loss: 7.5927
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 64 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3285... Generator Loss: 7.6319
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 65 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3287... Generator Loss: 7.5700
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 66 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3280... Generator Loss: 7.6104
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 67 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3289... Generator Loss: 7.6888
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 68 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3277... Generator Loss: 7.6043
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 69 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3281... Generator Loss: 7.5997
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 70 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3283... Generator Loss: 7.6458
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 71 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3282... Generator Loss: 7.6089
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 72 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3280... Generator Loss: 7.5551
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 73 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3273... Generator Loss: 7.6068
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 74 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3277... Generator Loss: 7.6144
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 75 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3271... Generator Loss: 7.6245
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 76 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3277... Generator Loss: 7.6777
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 77 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3278... Generator Loss: 7.6808
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 78 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3276... Generator Loss: 7.7133
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 79 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3277... Generator Loss: 7.7892
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 80 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3270... Generator Loss: 7.8448
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 81 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3273... Generator Loss: 7.8791
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 82 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3273... Generator Loss: 8.0002
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 83 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3271... Generator Loss: 8.0559
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 84 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3272... Generator Loss: 8.0593
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 85 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3269... Generator Loss: 8.1714
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 86 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3270... Generator Loss: 8.2764
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 87 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3274... Generator Loss: 8.2443
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 88 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3275... Generator Loss: 8.2683
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 89 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3274... Generator Loss: 8.3259
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 90 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.2948
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 91 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3269... Generator Loss: 8.2886
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 92 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3269... Generator Loss: 8.3296
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 93 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3270... Generator Loss: 8.2825
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 94 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3264... Generator Loss: 8.3234
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 95 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3272... Generator Loss: 8.3417
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 96 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.3218
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 97 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3272... Generator Loss: 8.3204
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 98 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.3638
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 99 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.3671
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 100 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.4631
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 101 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.5936
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 102 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.6015
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 103 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3268... Generator Loss: 8.6351
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 104 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3269... Generator Loss: 8.7157
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 105 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3268... Generator Loss: 8.6942
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 106 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3271... Generator Loss: 8.5753
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 107 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.6043
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 108 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3270... Generator Loss: 8.5750
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 109 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3264... Generator Loss: 8.5126
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 110 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.4617
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 111 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.5189
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 112 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.5321
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 113 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3266... Generator Loss: 8.5168
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 114 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 8.5956
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 115 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3268... Generator Loss: 8.6448
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 116 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3268... Generator Loss: 8.5991
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 117 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3267... Generator Loss: 8.6296
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 118 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3271... Generator Loss: 8.6454
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 119 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 8.6790
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 120 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 8.7510
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 121 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 8.8382
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 122 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.8493
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 123 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 8.9368
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 124 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 9.0070
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 125 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 8.9530
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 126 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 9.0172
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 127 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 9.0598
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 128 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 8.9636
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 129 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 8.9518
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 130 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 8.9712
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 131 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 8.9236
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 132 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 8.9484
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 133 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 8.9538
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 134 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 8.9021
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 135 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 8.9212
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 136 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 9.0192
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 137 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 9.0045
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 138 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 9.0507
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 139 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 9.1986
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 140 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 9.2135
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 141 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 9.2023
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 142 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3265... Generator Loss: 9.2773
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 143 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.2952
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 144 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.2905
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 145 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3264... Generator Loss: 9.3069
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 146 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.3578
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 147 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 9.3542
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 148 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.3625
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 149 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.3953
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 150 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.3553
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 151 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3261... Generator Loss: 9.2742
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 152 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 9.2285
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 153 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 9.1885
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 154 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.1645
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 155 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.1388
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 156 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.1506
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 157 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.1631
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 158 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3262... Generator Loss: 9.1452
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 159 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.2347
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 160 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.3412
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 161 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3263... Generator Loss: 9.4005
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 162 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.5755
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 163 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.6712
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 164 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.6499
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 165 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.7195
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 166 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.7208
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 167 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.6492
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 168 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3260... Generator Loss: 9.6390
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 169 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.6173
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 170 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.5670
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 171 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.5974
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 172 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.6275
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 173 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.6439
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 174 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.6697
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 175 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.6811
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 176 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 9.6751
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 177 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 9.7250
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 178 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 9.7481
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 179 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.7616
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 180 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.8236
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 181 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.8006
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 182 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.8279
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 183 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 9.8769
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 184 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.8830
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 185 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 9.9205
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 186 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.9873
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 187 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0055
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 188 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0718
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 189 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0762
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 190 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3259... Generator Loss: 10.0303
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 191 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0761
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 192 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 10.0530
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 193 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 9.9706
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 194 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.0096
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 195 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0192
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 196 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.9816
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 197 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.0625
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 198 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3258... Generator Loss: 10.0267
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 199 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 9.9875
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 200 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.0504
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 201 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.1063
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 202 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 10.1224
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 203 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.2206
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 204 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.2921
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 205 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.3093
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 206 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.3341
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 207 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3766
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 208 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3418
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 209 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3609
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 210 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.3999
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 211 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3876
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 212 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.4183
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 213 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.4527
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 214 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.5029
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 215 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.5817
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 216 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.6446
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 217 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.6753
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 218 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.6992
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 219 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.6866
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 220 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3257... Generator Loss: 10.5633
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 221 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.5080
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 222 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.4525
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 223 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3365
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 224 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.3190
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 225 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.3084
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 226 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.3306
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 227 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.4463
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 228 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.4726
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 229 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.5488
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 230 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.7126
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 231 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.7536
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 232 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.7961
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 233 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3256... Generator Loss: 10.8766
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 234 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.8776
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 235 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.8803
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 236 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.9423
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 237 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.9499
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 238 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.9661
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 239 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 11.0207
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 240 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 11.0108
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 241 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.8792
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 242 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.8090
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 243 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.6935
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 244 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.5891
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 245 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.5550
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 246 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.5133
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 247 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.5043
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 248 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 10.5498
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 249 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 10.5763
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 250 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.5639
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 251 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.6133
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 252 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3255... Generator Loss: 10.6532
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 253 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 10.7156
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 254 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 10.8114
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 255 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.8504
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 256 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 10.9673
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 257 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.0766
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 258 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.1382
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 259 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.1913
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 260 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 11.1800
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 261 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.1478
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 262 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.1234
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 263 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3254... Generator Loss: 11.0686
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 264 of epcoh 0
# Epoch 1/15... Discriminator Loss: 0.3253... Generator Loss: 11.0232
# 429
# ...
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 342 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.8681
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 343 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.8642
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 344 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.8608
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 345 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.8586
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 346 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.8101
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 347 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.7621
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 348 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.7051
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 349 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.6546
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 350 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.5864
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 351 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.5264
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 352 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4706
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 353 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4318
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 354 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3664
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 355 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2996
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 356 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2459
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 357 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2252
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 358 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2316
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 359 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2239
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 360 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2266
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 361 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2443
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 362 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0067
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 363 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.7258
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 364 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.4951
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 365 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.3171
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 366 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.1798
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 367 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.0755
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 368 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.0045
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 369 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9648
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 370 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9454
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 371 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9285
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 372 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9462
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 373 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9674
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 374 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 19.9958
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 375 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.0329
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 376 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.0752
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 377 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.1206
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 378 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.1698
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 379 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.2081
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 380 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.2654
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 381 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.2960
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 382 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.3461
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 383 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.3769
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 384 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.4288
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 385 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.4838
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 386 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.6066
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 387 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.7497
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 388 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.9248
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 389 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0418
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 390 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1278
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 391 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2742
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 392 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4248
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 393 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4653
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 394 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4416
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 395 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.4106
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 396 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3872
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 397 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3620
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 398 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3478
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 399 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3732
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 400 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3949
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 401 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3306
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 402 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2286
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 403 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1525
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 404 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1089
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 405 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0751
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 406 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0411
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 407 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0188
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 408 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0147
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 409 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.9836
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 410 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.9401
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 411 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.9180
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 412 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 20.9534
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 413 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0144
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 414 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0451
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 415 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0731
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 416 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0876
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 417 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1246
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 418 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1679
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 419 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1251
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 420 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0775
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 421 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0644
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 422 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0345
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 423 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0510
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 424 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.0858
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 425 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.1658
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 426 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2258
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 427 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.2651
# 429
# training.......
# batch_size(128, 28, 28, 1)
# discriminator done
# generator done
# end of iteration 428 of epcoh 14
# Epoch 15/15... Discriminator Loss: 0.3251... Generator Loss: 21.3056
# calling
# 15
# i'm here
